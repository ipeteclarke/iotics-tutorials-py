# %% [markdown]
# This script aims to show an example of the Search Twins operation.
#
# In particular it will search for the Twin Publisher implemented in the previous exercise.

# %%
from helpers.constants import (
    INDEX_URL,
    CREATED_BY,
    USER_KEY_NAME,
    USER_SEED,
)
from helpers.identity_interface import IdentityInterface
from helpers.utilities import make_api_call, print_property_grpc
from iotics.lib.grpc.helpers import create_property
from iotics.lib.grpc.iotics_api import IoticsApi
from iotics.lib.identity.api.high_level_api import (
    HighLevelIdentityApi,
    get_rest_high_level_identity_api,
)

# %%
HOST_URL:       str = "https://demo-cx.iotics.space"
USER_KEY_NAME:  str = "pclarke"
USER_SEED:      str = "713e9a6901e9ec61e0e97007d18b988913c76a786fd3bec5e722961b4c81e5e0"
AGENT_KEY_NAME: str = "demo-cx"
AGENT_SEED:     str = "713e9a6901e9ec61e0e97007d18b988913c76a786fd3bec5e722961b4c81e5e0"

# %%
iotics_index: dict = make_api_call(
    method="GET", endpoint=INDEX_URL.format(host_url=HOST_URL)
)
resolver_url: str = iotics_index.get("resolver")
grpc_url: str = iotics_index.get("grpc")

identity_api: HighLevelIdentityApi = get_rest_high_level_identity_api(
    resolver_url=resolver_url
)

identity_interface: IdentityInterface = IdentityInterface(
    grpc_endpoint=grpc_url, identity_api=identity_api
)

(
    user_identity,
    agent_identity,
) = identity_api.create_user_and_agent_with_auth_delegation(
    user_seed=bytes.fromhex(USER_SEED),
    user_key_name=USER_KEY_NAME,
    agent_seed=bytes.fromhex(AGENT_SEED),
    agent_key_name=AGENT_KEY_NAME,
)

identity_interface.refresh_token(
    user_identity=user_identity, agent_identity=agent_identity, token_duration=60
)

iotics_api = IoticsApi(auth=identity_interface)
# Out:
# Getting error HTTPSConnectionPool(host='demo-cx.iotics.space', port=443): Max retries exceeded with url: /index.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa52c4d56c0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fa52c4d56c0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='demo-cx.iotics.space', port=443): Max retries exceeded with url: /index.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa52c4d56c0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/gettingstarted/helpers/utilities.py:14, in make_api_call(method, endpoint, headers, payload)
#      13 try:
# ---> 14     req_resp: Response = request(
#      15         method=method, url=endpoint, headers=headers, json=payload
#      16     )
#      17     req_resp.raise_for_status()
#
# File /usr/local/lib/python3.10/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.10/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File /usr/local/lib/python3.10/dist-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='demo-cx.iotics.space', port=443): Max retries exceeded with url: /index.json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fa52c4d56c0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[3], line 1
# ----> 1 iotics_index: dict = make_api_call(
#       2     method="GET", endpoint=INDEX_URL.format(host_url=HOST_URL)
#       3 )
#       4 resolver_url: str = iotics_index.get("resolver")
#
# File ~/gettingstarted/helpers/utilities.py:21, in make_api_call(method, endpoint, headers, payload)
#      20     print("Getting error", ex)
# ---> 21     sys.exit(1)
#      23 return response
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %%
# We want to execute a Search Twins operation to find the Twin Publisher implemented in the previous exercise.
# To do that we need to define (1) the search criteria and (2) the type of results we want to get as a response.
# Regarding (1), there are 3 types of criteria (at least 1 criteria must be chosen):
# 1. a location with radius: find all the Twins around a specific geographic location;
# 2. a list of Twin Properties: find all the Twins that include a given list of Twin Properties (with an AND condition among Properties);
# 3. a string of text: find all the Twins that include one or more keywords within Twin Label or Twin Comment (with an OR condition among words).
# Regarding (2), the options are (1 must be chosen):
# 1. Full: return all the details of the Twins found: Twin ID, Host ID, Location, list of Twin Properties, list of Feed IDs, list of Input IDs;
# 2. Located: return only a subset of details of the Twins found: Twin ID, Host ID, Location;
# 3. Minimal (default): return only the minimum details of the Twins found: Twin ID, Host ID.

# %%
search_criteria = iotics_api.get_search_payload(
    properties=[
        create_property(key=CREATED_BY, value="Peter Clarke")
    ],
    # text="publisher",
    response_type="FULL",
)

# %%
# After defining the search criteria we can now execute the Search operation
# which blocks the execution of the code and returns an iterator which can be used to get the list of Twins found;.
# This method requires the following parameters:
# 1. Client App ID: a simple ID used to bind together request and response;
# 2. Search Payload: corresponds to the search criteria defined above;
# 3. Scope (LOCAL by default): defines where to search for Twins, either locally (LOCAL) in the Space defined by the 'HOST_URL'
#    or globally (GLOBAL) in the Network;
# 4. The language to conduct text searches in ("en" by default);
# 5. Timeout (3s by default): time after which the search iterator will stop blocking and listening for more replies.

# %%
twins_found_list = (
    []
)  # Let's define a list to add all the Twins found by the Search

for response in iotics_api.search_iter(
    client_app_id="search_twins", payload=search_criteria
):
    twins = response.payload.twins
    twins_found_list.extend(twins)

print(f"Found {len(twins_found_list)} Twin(s) based on the search criteria")
print("---")

for twin in twins_found_list:
    twin_id = twin.twinId.id
    host_id = twin.twinId.hostId
    location = twin.location
    twin_properties = twin.properties
    print(f"Twin ID: {twin_id}")
    print(f"Host ID: {host_id}")

    if location:
        lat = location.lat
        lon = location.lon
        print("Location:")
        print("   lat:", lat)
        print("   lon:", lon)

    print(f"Twin Properties ({len(twin_properties)}):")
    for twin_property in twin_properties:
        print_property_grpc(twin_property)

    # As mentioned in the description above, the Search operation (when response_type = FULL)
    # allows to return the Twin's Metadata along with the list of Feed IDs and Input IDs.
    # However in order to get the Feed's and/or Input's Metadata, the related Describe operation must be used.
    twin_feeds = twin.feeds
    print(f"Twin feeds ({len(twin_feeds)}):")

    for twin_feed in twin_feeds:
        feed_id = twin_feed.feedId.id
        print(f"-  Feed ID: {feed_id}")

    # Same as Feeds, in order to get the Input's Metadata, the Describe Input operation must be used.
    twin_inputs = twin.inputs
    print(f"Twin Inputs ({len(twin_inputs)}):")

    for twin_input in twin_inputs:
        input_id = twin_input.inputId.id
        print(f"-  Input ID: {input_id}")

    print("---")
# Out:
# Found 56 Twin(s) based on the search criteria
# ---
# Twin ID: did:iotics:iotAJmjPDB2nzydgNndrok9FY3VnKfRjbCuw
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.7701
#    lon: -1.094583
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Spit Refuge
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Red
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotAYSjjR1v8Mupt5jo4igYsGHmRNNZWBJ19
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.8270497
#    lon: -1.05479763
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: JPGL Custom Warehousing
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yard
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotAqqhHVnPXZFkPrfc43rrUW4E9F6uUrjrJ
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80924343
#    lon: -1.10296138
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 8
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Medium
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotAuya1GLLCPEkewBhrJF22zyHWvYy3wB8a
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 0.0
#    lon: 0.0
# Twin Properties (9):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#    URI Value: https://data.iotics.com/app#Model
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang Literal Value: https://schema.org/Hospital
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Hospital
#    Lang: en
# -  Key: https://data.iotics.com/app#color
#    String Literal Value: #7ed321
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#defines
#    URI Value: https://schema.org/Hospital
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotAwRvjd1FN3hDNCJvMxDjyaT4YY7YTDS4F
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.83292307
#    lon: -1.05937584
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: ProFrieght Warehouse
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Freight
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotAwa4mo86pDib9ptkvPnMbPSsmvsXGnLMj
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80784003
#    lon: -1.09036631
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Naval Dockyard
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yard
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotB3qnBE46rqbzmjb3dz1YvDKqJeRoZw9n1
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.76355
#    lon: -1.103283
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Mary Rose Wreck
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yellow
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotBAaBoP2qyEgByPoLfpBSLkqFZ3LazCuGr
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.794593
#    lon: -1.059029
# Twin Properties (8):
# -  Key: http://data.iotics.com/pip_demo#hasManufacturer
#    String Literal Value: Wemos
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor Milton+Village+Community+Association
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotBFCVXASsNHJmssQ8LSRae9qaWqhPFABbX
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80816164
#    lon: -1.0957347
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 2
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Medium
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotBjnrfxdpuEGkjDFpP3kNwiBjRjgiiDqNC
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.81825362
#    lon: -1.07330016
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: kings Academy College Park
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Secondary
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotC1e71keGx1QezrCvTzSU1h8kGA29AKUd2
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.8054338
#    lon: -1.099851
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 6
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Large
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotE1iKhJ73rfpG4GTeeuGR1awQuLEzBYS75
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.81363063
#    lon: -1.08810786
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: LoknStore Self Storage
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Self Store
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotEjp9spUrs2eusYBV74xE1YzM2yW6XX2Ni
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.79555905
#    lon: -1.08648109
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Somerstown Cenrtral Community Hub
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotAuya1GLLCPEkewBhrJF22zyHWvYy3wB8a
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Community
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 0.0
#    lon: 0.0
# Twin Properties (9):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#    URI Value: https://data.iotics.com/app#Model
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang Literal Value: Air Quality Sensors from GREEN Space in Workshop
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor GREEN
#    Lang: en
# -  Key: https://data.iotics.com/app#color
#    String Literal Value: #61a415
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#defines
#    URI Value: http://data.iotics.com/pip_demo#AirQualitySensor
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (1):
# -  Feed ID: 0000000670
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotGfneu33JobUyREJA6bAsJtL95nxWXvDbR
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.79131515
#    lon: -1.08615517
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Cottage Grove Primary School
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Primary
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 0.0
#    lon: 0.0
# Twin Properties (9):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#    URI Value: https://data.iotics.com/app#Model
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang Literal Value: https://schema.org/School
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: School
#    Lang: en
# -  Key: https://data.iotics.com/app#color
#    String Literal Value: #417505
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#defines
#    URI Value: https://schema.org/School
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotJQf5pXDHTyrgLnmwZnqS9cZ2hDnwrV5JJ
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.751617
#    lon: -1.08255
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Saddle
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Green
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotJX8pAxBoGkh4oSp7U51nyNP3u2XLdDGmy
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.795959
#    lon: -1.042714
# Twin Properties (8):
# -  Key: http://data.iotics.com/pip_demo#hasManufacturer
#    String Literal Value: Wemos
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor Langstone+Sports+Site+-+University+of+Portsmouth
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotJqD45vwQbhbL5jn15WCa7LA41dxewJiS1
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.74972203
#    lon: -1.07269215
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Horse Sand Fort
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yellow
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 0.0
#    lon: 0.0
# Twin Properties (9):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#    URI Value: https://data.iotics.com/app#Model
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang Literal Value: https://schema.org/BoatTerminal
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Naval Berth
#    Lang: en
# -  Key: https://data.iotics.com/app#color
#    String Literal Value: #a20417
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#defines
#    URI Value: https://schema.org/BoatTerminal
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotKnQ9usxkbEsHWEHPZqMxpdkUbW5ozTCx2
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80622707
#    lon: -1.09580623
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 5
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Medium
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotKvCmhzTZRmufipz2LxfebUA9zQiV6LFRm
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.79044984
#    lon: -1.09990865
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Saint Judes Primary School
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Primary
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotL3wHpp2DwZgJTpJbEYgiAczP1yHeBUNsf
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.73996291
#    lon: -1.09570761
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Solent Forts
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yellow
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotM2goDPyEUA62einTCkJBGfsZu1BkGWa6n
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80973897
#    lon: -1.10404243
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 9
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Large
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotMBMVqW54kyMNhudUBNdR8tF3q8g1kzy8x
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.81365989
#    lon: -1.08907389
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Fuel Store
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yard
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotMXYSQUi9fUrwHRjESgBJN4EZydPa6sUNq
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80973617
#    lon: -1.10218604
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 10
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Small
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotN2vSqrFXkJPGCXRCXEY4oFS6hDD1Th1fY
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.78686482
#    lon: -1.09081571
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Portsmouth High Junior School
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Secondary
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotNNxqe6hTpYfK2fT3GvMRwsRxQyMMm4Fgy
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.7741
#    lon: -1.089283
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Castle
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Green
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotP4S9qSyAN53689vSUvtqEpgVPK9WxMGsF
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.77957222
#    lon: -1.08849794
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: SouthSea Castle Lighthouse
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yellow
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotP7KWvd6KxiDEHSZ25RRDWb7mfx7f2rMmc
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.78936279
#    lon: -1.11245538
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Fort Blockhouse Lighthouse
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yellow
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotPAStr6wveXxHcsx1BbShMyb4G9BG3iVum
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80732351
#    lon: -1.1012968
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 7
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Small
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotPBqaNYgWmHwwB9C83KYBCTizs2jdScsYn
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.81070477
#    lon: -1.08383504
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: The Flying Bull Academy
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Secondary
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotPF8AEYgFnGimTyd5xLhfFqP9LmgnyKubK
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80761248
#    lon: -1.09696852
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 3
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Large
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotPe55PAfsKjJ4Crtt7AdVTSYntJAuGN4Y5
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.82267182
#    lon: -1.05656164
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Woodside Logistics
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Freight
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotQsTVvzmVHsHAJDtuefL4nQPys9t1uprvN
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.791647
#    lon: -1.099688
# Twin Properties (8):
# -  Key: http://data.iotics.com/pip_demo#hasManufacturer
#    String Literal Value: Wemos
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor Portsmouth+Museum+and+Art+Gallery
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotSKvS6yvJGemrDMhBvx5GMjqNmX9s5xmCM
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80075455
#    lon: -1.06153149
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Saint Mnary’s Community Health
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotAuya1GLLCPEkewBhrJF22zyHWvYy3wB8a
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Community
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotTavU42PXcgqWX7QRQQmLrB91nkUTUZNio
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.7962868
#    lon: -1.09372786
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: University of Portsmouth
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotH7t4hgBWTuvKRUeX5eDcqgS6vU7ecxgkW
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Further Education
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 0.0
#    lon: 0.0
# Twin Properties (9):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#    URI Value: https://data.iotics.com/app#Model
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang Literal Value: https://schema.org/Place
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Buoys
#    Lang: en
# -  Key: https://data.iotics.com/app#color
#    String Literal Value: #d0021b
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#defines
#    URI Value: https://schema.org/Place
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotU9BkcB5HBjgnPdsGWBWL9YcRfSa48ATgY
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.784817
#    lon: -1.10385
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: 3 Bar Lateral
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Green
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotUcQiH13dLpXezNpJVfSWG8b7inxNbWc13
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.782933
#    lon: -1.108067
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: 4 Bar Lteral Bout
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Red
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotUjnFE17QVZ1qMa1W88GqMrn5CsZJzMdwg
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.757083
#    lon: -1.090783
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: 5Q Outer Spit
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Red
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotUrMBdk3qLoShv73ryh1P4rMo1nP8htCpX
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.785953
#    lon: -1.088706
# Twin Properties (8):
# -  Key: http://data.iotics.com/pip_demo#hasManufacturer
#    String Literal Value: Wemos
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor Waverley+Road+Surgery
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotUzbZmHQvcN6vK1yEHEfRkphNqLN3nRCmN
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.780561
#    lon: -1.086315
# Twin Properties (8):
# -  Key: http://data.iotics.com/pip_demo#hasManufacturer
#    String Literal Value: Wemos
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor Southsea+Skatepark
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotV7umuUS9jkH3787vKigma8jU1uYPNSex5
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80714914
#    lon: -1.09693276
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 4
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Small
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotW2j97ZPotKBWeVbtvj8qhYetJNzsgMj9r
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.77585
#    lon: -1.107633
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Naval Exclusion Marker
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotU48rvncHnU4jKR87oZzrEw7oDeHmdKKoD
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yellow
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotW6KT2mm8ekr3qpXp3TCMt4hjBG5wWwtN2
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.83307681
#    lon: -1.06392064
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: JL Fright
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Freight
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotWabgv2WPWS9Et8PDsmeQGTUf2DBzdkHRc
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.79723659
#    lon: -1.10760134
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Portsmouth Harbour Rail Station
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Yard
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotWg7MatAZkLYY7G57ihUj4qNEucmWgfSpY
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.81158915
#    lon: -1.08832391
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: EW Shipping And Freight
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Freight
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXEEv97X8nLMBnMndvQksU8JpVNEwS9rdp
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.84952379
#    lon: -1.07043422
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Queen Alexandria Hospital
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotAuya1GLLCPEkewBhrJF22zyHWvYy3wB8a
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Hospital
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXP1ABRqBJ4SjX8ghNSfwZaBgAP5F7xvHu
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.79607878
#    lon: -1.10262551
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Mercastor Freight
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Freight
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 0.0
#    lon: 0.0
# Twin Properties (9):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#    URI Value: https://data.iotics.com/app#Model
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang Literal Value: https://schema.org/SelfStorage
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Warehouse
#    Lang: en
# -  Key: https://data.iotics.com/app#color
#    String Literal Value: #f5a623
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#defines
#    URI Value: https://schema.org/SelfStorage
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXYciup8tXr5Po9DLtJuUTdxTwFUYwVQEo
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80768409
#    lon: -1.08871943
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: http://data.iotics.com/public#none
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Access Self Storage
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotXYThhjAv8Hfae8hXKZ61iLegTTokx45c5
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/keywords
#    String Literal Value: Self Store
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXimaX3ArjssVGpB31A3FyXsoDBNApHDg3
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80206426
#    lon: -1.07737712
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Fratton Community Centre
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotAuya1GLLCPEkewBhrJF22zyHWvYy3wB8a
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Community
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXpGFw2xqUU8E9uMPg1FXu3o5tq6KPEGxu
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.79119392
#    lon: -1.11361143
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: 33 Field Hospital
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotAuya1GLLCPEkewBhrJF22zyHWvYy3wB8a
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Hospital
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotXtjtsaeJZprpd3RxVduR7q8BNb3NJseag
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.786312
#    lon: -1.036903
# Twin Properties (8):
# -  Key: http://data.iotics.com/pip_demo#hasManufacturer
#    String Literal Value: Wemos
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Air Quality Sensor Eastney+Beach
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotFbw9mcAHvEVEvHXhc1maeysV6mC9JPfKs
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# Twin feeds (0):
# Twin Inputs (0):
# ---
# Twin ID: did:iotics:iotY18JPouFXxrAw9BGGpWpxb1qC4bosXCbn
# Host ID: did:iotics:iotYxuwTpmTfTrAnN3AcR7euPXCQSDygWEsG
# Location:
#    lat: 50.80885317
#    lon: -1.09777318
# Twin Properties (8):
# -  Key: http://data.iotics.com/public#hostAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://data.iotics.com/public#hostMetadataAllowList
#    URI Value: did:iotics:iotAuPmU81qCUgSn3g8Kf4RJC82pWm3bqYt9
# -  Key: http://www.w3.org/2000/01/rdf-schema#comment
#    Lang: en
# -  Key: http://www.w3.org/2000/01/rdf-schema#label
#    Lang Literal Value: Basin No. 3 Berth 1
#    Lang: en
# -  Key: https://data.iotics.com/app#createdBy
#    String Literal Value: Peter Clarke
# -  Key: https://data.iotics.com/app#model
#    URI Value: did:iotics:iotKKw54uVhzLboMHRKLmnPfjc2GxNMzERzm
# -  Key: https://data.iotics.com/app#updatedBy
#    String Literal Value: Peter Clarke
# -  Key: https://schema.org/additionalType
#    String Literal Value: Small
# Twin feeds (0):
# Twin Inputs (0):
# ---
